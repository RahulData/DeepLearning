# %% [markdown]
# # Neural networks
# In this notebook, we explore 2 different neural network architectures that succeeded in predicting sales volumes for a kaggle competition.

# %% [markdown]
# ## Notebook settings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from scipy.stats import describe
import seaborn as sns
from pylab import rcParams

pd.options.display.max_columns = 12
pd.options.display.max_rows = 24

# disable warnings in Anaconda
warnings.simplefilter('ignore')

# plots inisde jupyter notebook
# %matplotlib inline

sns.set(style='darkgrid', palette='muted')
color_scheme = {
    'red': '#F1637A',
    'green': '#6ABB3E',
    'blue': '#3D8DEA',
    'black': '#000000'
}

# use svg for all plots within inline backend
# %config InlineBackend.figure_format = 'svg'

# increase default plot size
rcParams['figure.figsize'] = 8, 6

# %% [markdown]
# ## Loading data
# In order for this to work, download all datasets from kaggle competition:
# https://www.kaggle.com/c/demand-forecasting-kernels-only
# and place them in `../data/` folder.
# We could not append datasets to our repo because of copyrights.

# %%
df_train = pd.read_csv('DemandData/train.csv')
df_test = pd.read_csv('DemandData/test.csv')

# %% [markdown]
# Before we do anything, we want to have both sets in a format with 500 sales columns and 1 row for each day.

# %%
df_train.index = pd.to_datetime(df_train['date'])
df_train.drop('date', axis=1, inplace=True)
df_test.index = pd.to_datetime(df_test['date'])
df_test.drop('date', axis=1, inplace=True)

# %%
df_train.head(10)
# Out:
#             store  item  sales
# date
# 2013-01-01      1     1     13
# 2013-01-02      1     1     11
# 2013-01-03      1     1     14
# 2013-01-04      1     1     13
# 2013-01-05      1     1     10
# 2013-01-06      1     1     12
# 2013-01-07      1     1     10
# 2013-01-08      1     1      9
# 2013-01-09      1     1     12
# 2013-01-10      1     1      9

# %%
from itertools import product, starmap


def storeitems():
    return product(range(1,51), range(1,11))


def storeitems_column_names():
    return list(starmap(lambda i,s: f'item_{i}_store_{s}_sales', storeitems()))


def sales_by_storeitem(df):
    ret = pd.DataFrame(index=df.index.unique())
    for i, s in storeitems():
        ret[f'item_{i}_store_{s}_sales'] = df[(df['item'] == i) & (df['store'] == s)]['sales'].values
    return ret

# %%
df_train.head(5)
# Out:
#             store  item  sales
# date
# 2013-01-01      1     1     13
# 2013-01-02      1     1     11
# 2013-01-03      1     1     14
# 2013-01-04      1     1     13
# 2013-01-05      1     1     10

# %%
df_train = sales_by_storeitem(df_train)
# for test set, we just fill y values with zeros (they won't be used anyway)
df_test['sales'] = np.zeros(df_test.shape[0])
df_test = sales_by_storeitem(df_test)

# %%
df_test.head()
# Out:
#             item_1_store_1_sales  item_1_store_2_sales  item_1_store_3_sales  \
# date
# 2018-01-01                   0.0                   0.0                   0.0
# 2018-01-02                   0.0                   0.0                   0.0
# 2018-01-03                   0.0                   0.0                   0.0
# 2018-01-04                   0.0                   0.0                   0.0
# 2018-01-05                   0.0                   0.0                   0.0
#
#             item_1_store_4_sales  item_1_store_5_sales  item_1_store_6_sales  \
# date
# 2018-01-01                   0.0                   0.0                   0.0
# 2018-01-02                   0.0                   0.0                   0.0
# 2018-01-03                   0.0                   0.0                   0.0
# 2018-01-04                   0.0                   0.0                   0.0
# 2018-01-05                   0.0                   0.0                   0.0
#
#                      ...            item_50_store_5_sales  \
# date                 ...
# 2018-01-01           ...                              0.0
# 2018-01-02           ...                              0.0
# 2018-01-03           ...                              0.0
# 2018-01-04           ...                              0.0
# 2018-01-05           ...                              0.0
#
#             item_50_store_6_sales  item_50_store_7_sales  \
# date
# 2018-01-01                    0.0                    0.0
# 2018-01-02                    0.0                    0.0
# 2018-01-03                    0.0                    0.0
# 2018-01-04                    0.0                    0.0
# 2018-01-05                    0.0                    0.0
#
#             item_50_store_8_sales  item_50_store_9_sales  \
# date
# 2018-01-01                    0.0                    0.0
# 2018-01-02                    0.0                    0.0
# 2018-01-03                    0.0                    0.0
# 2018-01-04                    0.0                    0.0
# 2018-01-05                    0.0                    0.0
#
#             item_50_store_10_sales
# date
# 2018-01-01                     0.0
# 2018-01-02                     0.0
# 2018-01-03                     0.0
# 2018-01-04                     0.0
# 2018-01-05                     0.0
#
# [5 rows x 500 columns]

# %%
df_train.head(10)
# Out:
#             item_1_store_1_sales  item_1_store_2_sales  item_1_store_3_sales  \
# date
# 2013-01-01                    13                    12                    19
# 2013-01-02                    11                    16                     8
# 2013-01-03                    14                    16                    10
# 2013-01-04                    13                    20                    15
# 2013-01-05                    10                    16                    22
# 2013-01-06                    12                    18                    22
# 2013-01-07                    10                    12                     7
# 2013-01-08                     9                    11                    15
# 2013-01-09                    12                    16                     9
# 2013-01-10                     9                    10                     7
#
#             item_1_store_4_sales  item_1_store_5_sales  item_1_store_6_sales  \
# date
# 2013-01-01                    10                    11                    20
# 2013-01-02                    12                     9                     6
# 2013-01-03                     8                    12                    11
# 2013-01-04                    15                     8                     7
# 2013-01-05                    19                    13                    12
# 2013-01-06                    14                    15                     9
# 2013-01-07                    12                     6                    11
# 2013-01-08                    16                    11                     9
# 2013-01-09                    18                    13                    13
# 2013-01-10                    16                     9                     9
#
#                      ...            item_50_store_5_sales  \
# date                 ...
# 2013-01-01           ...                               19
# 2013-01-02           ...                               25
# 2013-01-03           ...                               28
# 2013-01-04           ...                               27
# 2013-01-05           ...                               31
# 2013-01-06           ...                               24
# 2013-01-07           ...                               12
# 2013-01-08           ...                               27
# 2013-01-09           ...                               25
# 2013-01-10           ...                               36
#
#             item_50_store_6_sales  item_50_store_7_sales  \
# date
# 2013-01-01                     20                     21
# 2013-01-02                     23                     30
# 2013-01-03                     38                     20
# 2013-01-04                     33                     27
# 2013-01-05                     33                     18
# 2013-01-06                     28                     26
# 2013-01-07                     25                     14
# 2013-01-08                     27                     27
# 2013-01-09                     26                     20
# 2013-01-10                     31                     20
#
#             item_50_store_8_sales  item_50_store_9_sales  \
# date
# 2013-01-01                     45                     36
# 2013-01-02                     54                     44
# 2013-01-03                     54                     29
# 2013-01-04                     52                     43
# 2013-01-05                     48                     53
# 2013-01-06                     51                     38
# 2013-01-07                     37                     34
# 2013-01-08                     44                     34
# 2013-01-09                     46                     24
# 2013-01-10                     44                     40
#
#             item_50_store_10_sales
# date
# 2013-01-01                      33
# 2013-01-02                      37
# 2013-01-03                      46
# 2013-01-04                      51
# 2013-01-05                      41
# 2013-01-06                      41
# 2013-01-07                      38
# 2013-01-08                      33
# 2013-01-09                      35
# 2013-01-10                      41
#
# [10 rows x 500 columns]

# %%
df_train.shape
# Out:
# (1826, 500)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2013-01-01 to 2017-12-31
# Columns: 500 entries, item_1_store_1_sales to item_50_store_10_sales
# dtypes: int64(500)
# memory usage: 7.0 MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90 entries, 2018-01-01 to 2018-03-31
# Columns: 500 entries, item_1_store_1_sales to item_50_store_10_sales
# dtypes: float64(500)
# memory usage: 352.3 KB

# %% [markdown]
# We combine data to prepare it for the model, and later split back into train and test set, not to repeat same transformations twice.

# %%
# make sure all column names are the same and in the same order
col_names = list(zip(df_test.columns, df_train.columns))
for cn in col_names:
    assert cn[0] == cn[1]

# %%
df_test['is_test'] = np.repeat(True, df_test.shape[0])
df_train['is_test'] = np.repeat(False, df_train.shape[0])
df_total = pd.concat([df_train, df_test])
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1916 entries, 2013-01-01 to 2018-03-31
# Columns: 501 entries, item_1_store_1_sales to is_test
# dtypes: bool(1), float64(500)
# memory usage: 7.3 MB

# %% [markdown]
# ### Features
# One-hot encoding day of week and month of year to make sure the networks recognize the seasonality in the data.

# %%
weekday_df = pd.get_dummies(df_total.index.weekday, prefix='weekday')
weekday_df.index = df_total.index

# %%
month_df = pd.get_dummies(df_total.index.month, prefix='month')
month_df.index =  df_total.index

# %%
weekday_df.head()
# Out:
#             weekday_0  weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# date
# 2013-01-01          0          1          0          0          0          0
# 2013-01-02          0          0          1          0          0          0
# 2013-01-03          0          0          0          1          0          0
# 2013-01-04          0          0          0          0          1          0
# 2013-01-05          0          0          0          0          0          1
#
#             weekday_6
# date
# 2013-01-01          0
# 2013-01-02          0
# 2013-01-03          0
# 2013-01-04          0
# 2013-01-05          0

# %%
month_df.head()
# Out:
#             month_1  month_2  month_3  month_4  month_5  month_6  month_7  \
# date
# 2013-01-01        1        0        0        0        0        0        0
# 2013-01-02        1        0        0        0        0        0        0
# 2013-01-03        1        0        0        0        0        0        0
# 2013-01-04        1        0        0        0        0        0        0
# 2013-01-05        1        0        0        0        0        0        0
#
#             month_8  month_9  month_10  month_11  month_12
# date
# 2013-01-01        0        0         0         0         0
# 2013-01-02        0        0         0         0         0
# 2013-01-03        0        0         0         0         0
# 2013-01-04        0        0         0         0         0
# 2013-01-05        0        0         0         0         0

# %%
df_total.head()
# Out:
#             item_1_store_1_sales  item_1_store_2_sales  item_1_store_3_sales  \
# date
# 2013-01-01                  13.0                  12.0                  19.0
# 2013-01-02                  11.0                  16.0                   8.0
# 2013-01-03                  14.0                  16.0                  10.0
# 2013-01-04                  13.0                  20.0                  15.0
# 2013-01-05                  10.0                  16.0                  22.0
#
#             item_1_store_4_sales  item_1_store_5_sales  item_1_store_6_sales  \
# date
# 2013-01-01                  10.0                  11.0                  20.0
# 2013-01-02                  12.0                   9.0                   6.0
# 2013-01-03                   8.0                  12.0                  11.0
# 2013-01-04                  15.0                   8.0                   7.0
# 2013-01-05                  19.0                  13.0                  12.0
#
#              ...     item_50_store_6_sales  item_50_store_7_sales  \
# date         ...
# 2013-01-01   ...                      20.0                   21.0
# 2013-01-02   ...                      23.0                   30.0
# 2013-01-03   ...                      38.0                   20.0
# 2013-01-04   ...                      33.0                   27.0
# 2013-01-05   ...                      33.0                   18.0
#
#             item_50_store_8_sales  item_50_store_9_sales  \
# date
# 2013-01-01                   45.0                   36.0
# 2013-01-02                   54.0                   44.0
# 2013-01-03                   54.0                   29.0
# 2013-01-04                   52.0                   43.0
# 2013-01-05                   48.0                   53.0
#
#             item_50_store_10_sales  is_test
# date
# 2013-01-01                    33.0    False
# 2013-01-02                    37.0    False
# 2013-01-03                    46.0    False
# 2013-01-04                    51.0    False
# 2013-01-05                    41.0    False
#
# [5 rows x 501 columns]

# %%
df_total = pd.concat([weekday_df, month_df, df_total], axis=1)

# %%
df_total.columns
# Out:
# Index(['weekday_0', 'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4',
#        'weekday_5', 'weekday_6', 'month_1', 'month_2', 'month_3',
#        ...
#        'item_50_store_2_sales', 'item_50_store_3_sales',
#        'item_50_store_4_sales', 'item_50_store_5_sales',
#        'item_50_store_6_sales', 'item_50_store_7_sales',
#        'item_50_store_8_sales', 'item_50_store_9_sales',
#        'item_50_store_10_sales', 'is_test'],
#       dtype='object', length=520)

# %%
# assert df_total.isna().any().any() == False
assert df_total.isnull().any().any() == False

# %% [markdown]
# We also want to append sales from previous day to each row, which we will then use as input data.

# %%
def shift_series(series, days):
    return series.transform(lambda x: x.shift(days))


def shift_series_in_df(df, series_names=[], days_delta=90):
    ret = pd.DataFrame(index=df.index.copy())
    str_sgn = 'future' if np.sign(days_delta) < 0 else 'past'
    for sn in series_names:
        ret[f'{sn}_{str_sgn}_{np.abs(days_delta)}'] = shift_series(df[sn], days_delta)
    return ret

    
def stack_shifted_sales(df, days_deltas=[1, 90, 360]):
    names = storeitems_column_names()
    dfs = [df.copy()]
    for delta in days_deltas:
        shifted = shift_series_in_df(df, series_names=names, days_delta=delta)
        dfs.append(shifted)
#     return pd.concat(dfs, axis=1, sort=False, copy=False)
    return pd.concat(dfs, axis=1, copy=False)

# %%
df_total = stack_shifted_sales(df_total, days_deltas=[1])
df_total.dropna(inplace=True)

# %%
df_total.iloc[:,19:]
# Out:
#             item_1_store_1_sales  item_1_store_2_sales  item_1_store_3_sales  \
# date
# 2013-01-02                  11.0                  16.0                   8.0
# 2013-01-03                  14.0                  16.0                  10.0
# 2013-01-04                  13.0                  20.0                  15.0
# 2013-01-05                  10.0                  16.0                  22.0
# 2013-01-06                  12.0                  18.0                  22.0
# 2013-01-07                  10.0                  12.0                   7.0
# 2013-01-08                   9.0                  11.0                  15.0
# 2013-01-09                  12.0                  16.0                   9.0
# 2013-01-10                   9.0                  10.0                   7.0
# 2013-01-11                   9.0                  15.0                  19.0
# 2013-01-12                   7.0                  22.0                  16.0
# 2013-01-13                  10.0                  30.0                  14.0
# ...                          ...                   ...                   ...
# 2018-03-20                   0.0                   0.0                   0.0
# 2018-03-21                   0.0                   0.0                   0.0
# 2018-03-22                   0.0                   0.0                   0.0
# 2018-03-23                   0.0                   0.0                   0.0
# 2018-03-24                   0.0                   0.0                   0.0
# 2018-03-25                   0.0                   0.0                   0.0
# 2018-03-26                   0.0                   0.0                   0.0
# 2018-03-27                   0.0                   0.0                   0.0
# 2018-03-28                   0.0                   0.0                   0.0
# 2018-03-29                   0.0                   0.0                   0.0
# 2018-03-30                   0.0                   0.0                   0.0
# 2018-03-31                   0.0                   0.0                   0.0
#
#             item_1_store_4_sales  item_1_store_5_sales  item_1_store_6_sales  \
# date
# 2013-01-02                  12.0                   9.0                   6.0
# 2013-01-03                   8.0                  12.0                  11.0
# 2013-01-04                  15.0                   8.0                   7.0
# 2013-01-05                  19.0                  13.0                  12.0
# 2013-01-06                  14.0                  15.0                   9.0
# 2013-01-07                  12.0                   6.0                  11.0
# 2013-01-08                  16.0                  11.0                   9.0
# 2013-01-09                  18.0                  13.0                  13.0
# 2013-01-10                  16.0                   9.0                   9.0
# 2013-01-11                  14.0                   9.0                  11.0
# 2013-01-12                  10.0                   8.0                  13.0
# 2013-01-13                  21.0                  22.0                  12.0
# ...                          ...                   ...                   ...
# 2018-03-20                   0.0                   0.0                   0.0
# 2018-03-21                   0.0                   0.0                   0.0
# 2018-03-22                   0.0                   0.0                   0.0
# 2018-03-23                   0.0                   0.0                   0.0
# 2018-03-24                   0.0                   0.0                   0.0
# 2018-03-25                   0.0                   0.0                   0.0
# 2018-03-26                   0.0                   0.0                   0.0
# 2018-03-27                   0.0                   0.0                   0.0
# 2018-03-28                   0.0                   0.0                   0.0
# 2018-03-29                   0.0                   0.0                   0.0
# 2018-03-30                   0.0                   0.0                   0.0
# 2018-03-31                   0.0                   0.0                   0.0
#
#                         ...                item_50_store_5_sales_past_1  \
# date                    ...
# 2013-01-02              ...                                        19.0
# 2013-01-03              ...                                        25.0
# 2013-01-04              ...                                        28.0
# 2013-01-05              ...                                        27.0
# 2013-01-06              ...                                        31.0
# 2013-01-07              ...                                        24.0
# 2013-01-08              ...                                        12.0
# 2013-01-09              ...                                        27.0
# 2013-01-10              ...                                        25.0
# 2013-01-11              ...                                        36.0
# 2013-01-12              ...                                        30.0
# 2013-01-13              ...                                        42.0
# ...                     ...                                         ...
# 2018-03-20              ...                                         0.0
# 2018-03-21              ...                                         0.0
# 2018-03-22              ...                                         0.0
# 2018-03-23              ...                                         0.0
# 2018-03-24              ...                                         0.0
# 2018-03-25              ...                                         0.0
# 2018-03-26              ...                                         0.0
# 2018-03-27              ...                                         0.0
# 2018-03-28              ...                                         0.0
# 2018-03-29              ...                                         0.0
# 2018-03-30              ...                                         0.0
# 2018-03-31              ...                                         0.0
#
#             item_50_store_6_sales_past_1  item_50_store_7_sales_past_1  \
# date
# 2013-01-02                          20.0                          21.0
# 2013-01-03                          23.0                          30.0
# 2013-01-04                          38.0                          20.0
# 2013-01-05                          33.0                          27.0
# 2013-01-06                          33.0                          18.0
# 2013-01-07                          28.0                          26.0
# 2013-01-08                          25.0                          14.0
# 2013-01-09                          27.0                          27.0
# 2013-01-10                          26.0                          20.0
# 2013-01-11                          31.0                          20.0
# 2013-01-12                          28.0                          24.0
# 2013-01-13                          38.0                          32.0
# ...                                  ...                           ...
# 2018-03-20                           0.0                           0.0
# 2018-03-21                           0.0                           0.0
# 2018-03-22                           0.0                           0.0
# 2018-03-23                           0.0                           0.0
# 2018-03-24                           0.0                           0.0
# 2018-03-25                           0.0                           0.0
# 2018-03-26                           0.0                           0.0
# 2018-03-27                           0.0                           0.0
# 2018-03-28                           0.0                           0.0
# 2018-03-29                           0.0                           0.0
# 2018-03-30                           0.0                           0.0
# 2018-03-31                           0.0                           0.0
#
#             item_50_store_8_sales_past_1  item_50_store_9_sales_past_1  \
# date
# 2013-01-02                          45.0                          36.0
# 2013-01-03                          54.0                          44.0
# 2013-01-04                          54.0                          29.0
# 2013-01-05                          52.0                          43.0
# 2013-01-06                          48.0                          53.0
# 2013-01-07                          51.0                          38.0
# 2013-01-08                          37.0                          34.0
# 2013-01-09                          44.0                          34.0
# 2013-01-10                          46.0                          24.0
# 2013-01-11                          44.0                          40.0
# 2013-01-12                          51.0                          46.0
# 2013-01-13                          59.0                          43.0
# ...                                  ...                           ...
# 2018-03-20                           0.0                           0.0
# 2018-03-21                           0.0                           0.0
# 2018-03-22                           0.0                           0.0
# 2018-03-23                           0.0                           0.0
# 2018-03-24                           0.0                           0.0
# 2018-03-25                           0.0                           0.0
# 2018-03-26                           0.0                           0.0
# 2018-03-27                           0.0                           0.0
# 2018-03-28                           0.0                           0.0
# 2018-03-29                           0.0                           0.0
# 2018-03-30                           0.0                           0.0
# 2018-03-31                           0.0                           0.0
#
#             item_50_store_10_sales_past_1
# date
# 2013-01-02                           33.0
# 2013-01-03                           37.0
# 2013-01-04                           46.0
# 2013-01-05                           51.0
# 2013-01-06                           41.0
# 2013-01-07                           41.0
# 2013-01-08                           38.0
# 2013-01-09                           33.0
# 2013-01-10                           35.0
# 2013-01-11                           41.0
# 2013-01-12                           36.0
# 2013-01-13                           53.0
# ...                                   ...
# 2018-03-20                            0.0
# 2018-03-21                            0.0
# 2018-03-22                            0.0
# 2018-03-23                            0.0
# 2018-03-24                            0.0
# 2018-03-25                            0.0
# 2018-03-26                            0.0
# 2018-03-27                            0.0
# 2018-03-28                            0.0
# 2018-03-29                            0.0
# 2018-03-30                            0.0
# 2018-03-31                            0.0
#
# [1915 rows x 1001 columns]

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1915 entries, 2013-01-02 to 2018-03-31
# Freq: D
# Columns: 1020 entries, weekday_0 to item_50_store_10_sales_past_1
# dtypes: bool(1), float64(1000), uint8(19)
# memory usage: 14.7 MB

# %% [markdown]
# We need to make sure that stacked and not-stacked sales columns appar in the same order. We do this by sorting the names (as strings), which works fine because we only need 1 past day for the network (see regression models and their rolling mechanism if you are interested in rolling more than 1 past days of sales as input).

# %%
sales_cols = [col for col in df_total.columns if '_sales' in col and '_sales_' not in col]
stacked_sales_cols = [col for col in df_total.columns if '_sales_' in col]
other_cols = [col for col in df_total.columns if col not in set(sales_cols) and col not in set(stacked_sales_cols)]

sales_cols = sorted(sales_cols)
stacked_sales_cols = sorted(stacked_sales_cols)

new_cols = other_cols + stacked_sales_cols + sales_cols

# %%
new_cols
# Out:
# ['weekday_0',
#  'weekday_1',
#  'weekday_2',
#  'weekday_3',
#  'weekday_4',
#  'weekday_5',
#  'weekday_6',
#  'month_1',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'is_test',
#  'item_10_store_10_sales_past_1',
#  'item_10_store_1_sales_past_1',
#  'item_10_store_2_sales_past_1',
#  'item_10_store_3_sales_past_1',
#  'item_10_store_4_sales_past_1',
#  'item_10_store_5_sales_past_1',
#  'item_10_store_6_sales_past_1',
#  'item_10_store_7_sales_past_1',
#  'item_10_store_8_sales_past_1',
#  'item_10_store_9_sales_past_1',
#  'item_11_store_10_sales_past_1',
#  'item_11_store_1_sales_past_1',
#  'item_11_store_2_sales_past_1',
#  'item_11_store_3_sales_past_1',
#  'item_11_store_4_sales_past_1',
#  'item_11_store_5_sales_past_1',
#  'item_11_store_6_sales_past_1',
#  'item_11_store_7_sales_past_1',
#  'item_11_store_8_sales_past_1',
#  'item_11_store_9_sales_past_1',
#  'item_12_store_10_sales_past_1',
#  'item_12_store_1_sales_past_1',
#  'item_12_store_2_sales_past_1',
#  'item_12_store_3_sales_past_1',
#  'item_12_store_4_sales_past_1',
#  'item_12_store_5_sales_past_1',
#  'item_12_store_6_sales_past_1',
#  'item_12_store_7_sales_past_1',
#  'item_12_store_8_sales_past_1',
#  'item_12_store_9_sales_past_1',
#  'item_13_store_10_sales_past_1',
#  'item_13_store_1_sales_past_1',
#  'item_13_store_2_sales_past_1',
#  'item_13_store_3_sales_past_1',
#  'item_13_store_4_sales_past_1',
#  'item_13_store_5_sales_past_1',
#  'item_13_store_6_sales_past_1',
#  'item_13_store_7_sales_past_1',
#  'item_13_store_8_sales_past_1',
#  'item_13_store_9_sales_past_1',
#  'item_14_store_10_sales_past_1',
#  'item_14_store_1_sales_past_1',
#  'item_14_store_2_sales_past_1',
#  'item_14_store_3_sales_past_1',
#  'item_14_store_4_sales_past_1',
#  'item_14_store_5_sales_past_1',
#  'item_14_store_6_sales_past_1',
#  'item_14_store_7_sales_past_1',
#  'item_14_store_8_sales_past_1',
#  'item_14_store_9_sales_past_1',
#  'item_15_store_10_sales_past_1',
#  'item_15_store_1_sales_past_1',
#  'item_15_store_2_sales_past_1',
#  'item_15_store_3_sales_past_1',
#  'item_15_store_4_sales_past_1',
#  'item_15_store_5_sales_past_1',
#  'item_15_store_6_sales_past_1',
#  'item_15_store_7_sales_past_1',
#  'item_15_store_8_sales_past_1',
#  'item_15_store_9_sales_past_1',
#  'item_16_store_10_sales_past_1',
#  'item_16_store_1_sales_past_1',
#  'item_16_store_2_sales_past_1',
#  'item_16_store_3_sales_past_1',
#  'item_16_store_4_sales_past_1',
#  'item_16_store_5_sales_past_1',
#  'item_16_store_6_sales_past_1',
#  'item_16_store_7_sales_past_1',
#  'item_16_store_8_sales_past_1',
#  'item_16_store_9_sales_past_1',
#  'item_17_store_10_sales_past_1',
#  'item_17_store_1_sales_past_1',
#  'item_17_store_2_sales_past_1',
#  'item_17_store_3_sales_past_1',
#  'item_17_store_4_sales_past_1',
#  'item_17_store_5_sales_past_1',
#  'item_17_store_6_sales_past_1',
#  'item_17_store_7_sales_past_1',
#  'item_17_store_8_sales_past_1',
#  'item_17_store_9_sales_past_1',
#  'item_18_store_10_sales_past_1',
#  'item_18_store_1_sales_past_1',
#  'item_18_store_2_sales_past_1',
#  'item_18_store_3_sales_past_1',
#  'item_18_store_4_sales_past_1',
#  'item_18_store_5_sales_past_1',
#  'item_18_store_6_sales_past_1',
#  'item_18_store_7_sales_past_1',
#  'item_18_store_8_sales_past_1',
#  'item_18_store_9_sales_past_1',
#  'item_19_store_10_sales_past_1',
#  'item_19_store_1_sales_past_1',
#  'item_19_store_2_sales_past_1',
#  'item_19_store_3_sales_past_1',
#  'item_19_store_4_sales_past_1',
#  'item_19_store_5_sales_past_1',
#  'item_19_store_6_sales_past_1',
#  'item_19_store_7_sales_past_1',
#  'item_19_store_8_sales_past_1',
#  'item_19_store_9_sales_past_1',
#  'item_1_store_10_sales_past_1',
#  'item_1_store_1_sales_past_1',
#  'item_1_store_2_sales_past_1',
#  'item_1_store_3_sales_past_1',
#  'item_1_store_4_sales_past_1',
#  'item_1_store_5_sales_past_1',
#  'item_1_store_6_sales_past_1',
#  'item_1_store_7_sales_past_1',
#  'item_1_store_8_sales_past_1',
#  'item_1_store_9_sales_past_1',
#  'item_20_store_10_sales_past_1',
#  'item_20_store_1_sales_past_1',
#  'item_20_store_2_sales_past_1',
#  'item_20_store_3_sales_past_1',
#  'item_20_store_4_sales_past_1',
#  'item_20_store_5_sales_past_1',
#  'item_20_store_6_sales_past_1',
#  'item_20_store_7_sales_past_1',
#  'item_20_store_8_sales_past_1',
#  'item_20_store_9_sales_past_1',
#  'item_21_store_10_sales_past_1',
#  'item_21_store_1_sales_past_1',
#  'item_21_store_2_sales_past_1',
#  'item_21_store_3_sales_past_1',
#  'item_21_store_4_sales_past_1',
#  'item_21_store_5_sales_past_1',
#  'item_21_store_6_sales_past_1',
#  'item_21_store_7_sales_past_1',
#  'item_21_store_8_sales_past_1',
#  'item_21_store_9_sales_past_1',
#  'item_22_store_10_sales_past_1',
#  'item_22_store_1_sales_past_1',
#  'item_22_store_2_sales_past_1',
#  'item_22_store_3_sales_past_1',
#  'item_22_store_4_sales_past_1',
#  'item_22_store_5_sales_past_1',
#  'item_22_store_6_sales_past_1',
#  'item_22_store_7_sales_past_1',
#  'item_22_store_8_sales_past_1',
#  'item_22_store_9_sales_past_1',
#  'item_23_store_10_sales_past_1',
#  'item_23_store_1_sales_past_1',
#  'item_23_store_2_sales_past_1',
#  'item_23_store_3_sales_past_1',
#  'item_23_store_4_sales_past_1',
#  'item_23_store_5_sales_past_1',
#  'item_23_store_6_sales_past_1',
#  'item_23_store_7_sales_past_1',
#  'item_23_store_8_sales_past_1',
#  'item_23_store_9_sales_past_1',
#  'item_24_store_10_sales_past_1',
#  'item_24_store_1_sales_past_1',
#  'item_24_store_2_sales_past_1',
#  'item_24_store_3_sales_past_1',
#  'item_24_store_4_sales_past_1',
#  'item_24_store_5_sales_past_1',
#  'item_24_store_6_sales_past_1',
#  'item_24_store_7_sales_past_1',
#  'item_24_store_8_sales_past_1',
#  'item_24_store_9_sales_past_1',
#  'item_25_store_10_sales_past_1',
#  'item_25_store_1_sales_past_1',
#  'item_25_store_2_sales_past_1',
#  'item_25_store_3_sales_past_1',
#  'item_25_store_4_sales_past_1',
#  'item_25_store_5_sales_past_1',
#  'item_25_store_6_sales_past_1',
#  'item_25_store_7_sales_past_1',
#  'item_25_store_8_sales_past_1',
#  'item_25_store_9_sales_past_1',
#  'item_26_store_10_sales_past_1',
#  'item_26_store_1_sales_past_1',
#  'item_26_store_2_sales_past_1',
#  'item_26_store_3_sales_past_1',
#  'item_26_store_4_sales_past_1',
#  'item_26_store_5_sales_past_1',
#  'item_26_store_6_sales_past_1',
#  'item_26_store_7_sales_past_1',
#  'item_26_store_8_sales_past_1',
#  'item_26_store_9_sales_past_1',
#  'item_27_store_10_sales_past_1',
#  'item_27_store_1_sales_past_1',
#  'item_27_store_2_sales_past_1',
#  'item_27_store_3_sales_past_1',
#  'item_27_store_4_sales_past_1',
#  'item_27_store_5_sales_past_1',
#  'item_27_store_6_sales_past_1',
#  'item_27_store_7_sales_past_1',
#  'item_27_store_8_sales_past_1',
#  'item_27_store_9_sales_past_1',
#  'item_28_store_10_sales_past_1',
#  'item_28_store_1_sales_past_1',
#  'item_28_store_2_sales_past_1',
#  'item_28_store_3_sales_past_1',
#  'item_28_store_4_sales_past_1',
#  'item_28_store_5_sales_past_1',
#  'item_28_store_6_sales_past_1',
#  'item_28_store_7_sales_past_1',
#  'item_28_store_8_sales_past_1',
#  'item_28_store_9_sales_past_1',
#  'item_29_store_10_sales_past_1',
#  'item_29_store_1_sales_past_1',
#  'item_29_store_2_sales_past_1',
#  'item_29_store_3_sales_past_1',
#  'item_29_store_4_sales_past_1',
#  'item_29_store_5_sales_past_1',
#  'item_29_store_6_sales_past_1',
#  'item_29_store_7_sales_past_1',
#  'item_29_store_8_sales_past_1',
#  'item_29_store_9_sales_past_1',
#  'item_2_store_10_sales_past_1',
#  'item_2_store_1_sales_past_1',
#  'item_2_store_2_sales_past_1',
#  'item_2_store_3_sales_past_1',
#  'item_2_store_4_sales_past_1',
#  'item_2_store_5_sales_past_1',
#  'item_2_store_6_sales_past_1',
#  'item_2_store_7_sales_past_1',
#  'item_2_store_8_sales_past_1',
#  'item_2_store_9_sales_past_1',
#  'item_30_store_10_sales_past_1',
#  'item_30_store_1_sales_past_1',
#  'item_30_store_2_sales_past_1',
#  'item_30_store_3_sales_past_1',
#  'item_30_store_4_sales_past_1',
#  'item_30_store_5_sales_past_1',
#  'item_30_store_6_sales_past_1',
#  'item_30_store_7_sales_past_1',
#  'item_30_store_8_sales_past_1',
#  'item_30_store_9_sales_past_1',
#  'item_31_store_10_sales_past_1',
#  'item_31_store_1_sales_past_1',
#  'item_31_store_2_sales_past_1',
#  'item_31_store_3_sales_past_1',
#  'item_31_store_4_sales_past_1',
#  'item_31_store_5_sales_past_1',
#  'item_31_store_6_sales_past_1',
#  'item_31_store_7_sales_past_1',
#  'item_31_store_8_sales_past_1',
#  'item_31_store_9_sales_past_1',
#  'item_32_store_10_sales_past_1',
#  'item_32_store_1_sales_past_1',
#  'item_32_store_2_sales_past_1',
#  'item_32_store_3_sales_past_1',
#  'item_32_store_4_sales_past_1',
#  'item_32_store_5_sales_past_1',
#  'item_32_store_6_sales_past_1',
#  'item_32_store_7_sales_past_1',
#  'item_32_store_8_sales_past_1',
#  'item_32_store_9_sales_past_1',
#  'item_33_store_10_sales_past_1',
#  'item_33_store_1_sales_past_1',
#  'item_33_store_2_sales_past_1',
#  'item_33_store_3_sales_past_1',
#  'item_33_store_4_sales_past_1',
#  'item_33_store_5_sales_past_1',
#  'item_33_store_6_sales_past_1',
#  'item_33_store_7_sales_past_1',
#  'item_33_store_8_sales_past_1',
#  'item_33_store_9_sales_past_1',
#  'item_34_store_10_sales_past_1',
#  'item_34_store_1_sales_past_1',
#  'item_34_store_2_sales_past_1',
#  'item_34_store_3_sales_past_1',
#  'item_34_store_4_sales_past_1',
#  'item_34_store_5_sales_past_1',
#  'item_34_store_6_sales_past_1',
#  'item_34_store_7_sales_past_1',
#  'item_34_store_8_sales_past_1',
#  'item_34_store_9_sales_past_1',
#  'item_35_store_10_sales_past_1',
#  'item_35_store_1_sales_past_1',
#  'item_35_store_2_sales_past_1',
#  'item_35_store_3_sales_past_1',
#  'item_35_store_4_sales_past_1',
#  'item_35_store_5_sales_past_1',
#  'item_35_store_6_sales_past_1',
#  'item_35_store_7_sales_past_1',
#  'item_35_store_8_sales_past_1',
#  'item_35_store_9_sales_past_1',
#  'item_36_store_10_sales_past_1',
#  'item_36_store_1_sales_past_1',
#  'item_36_store_2_sales_past_1',
#  'item_36_store_3_sales_past_1',
#  'item_36_store_4_sales_past_1',
#  'item_36_store_5_sales_past_1',
#  'item_36_store_6_sales_past_1',
#  'item_36_store_7_sales_past_1',
#  'item_36_store_8_sales_past_1',
#  'item_36_store_9_sales_past_1',
#  'item_37_store_10_sales_past_1',
#  'item_37_store_1_sales_past_1',
#  'item_37_store_2_sales_past_1',
#  'item_37_store_3_sales_past_1',
#  'item_37_store_4_sales_past_1',
#  'item_37_store_5_sales_past_1',
#  'item_37_store_6_sales_past_1',
#  'item_37_store_7_sales_past_1',
#  'item_37_store_8_sales_past_1',
#  'item_37_store_9_sales_past_1',
#  'item_38_store_10_sales_past_1',
#  'item_38_store_1_sales_past_1',
#  'item_38_store_2_sales_past_1',
#  'item_38_store_3_sales_past_1',
#  'item_38_store_4_sales_past_1',
#  'item_38_store_5_sales_past_1',
#  'item_38_store_6_sales_past_1',
#  'item_38_store_7_sales_past_1',
#  'item_38_store_8_sales_past_1',
#  'item_38_store_9_sales_past_1',
#  'item_39_store_10_sales_past_1',
#  'item_39_store_1_sales_past_1',
#  'item_39_store_2_sales_past_1',
#  'item_39_store_3_sales_past_1',
#  'item_39_store_4_sales_past_1',
#  'item_39_store_5_sales_past_1',
#  'item_39_store_6_sales_past_1',
#  'item_39_store_7_sales_past_1',
#  'item_39_store_8_sales_past_1',
#  'item_39_store_9_sales_past_1',
#  'item_3_store_10_sales_past_1',
#  'item_3_store_1_sales_past_1',
#  'item_3_store_2_sales_past_1',
#  'item_3_store_3_sales_past_1',
#  'item_3_store_4_sales_past_1',
#  'item_3_store_5_sales_past_1',
#  'item_3_store_6_sales_past_1',
#  'item_3_store_7_sales_past_1',
#  'item_3_store_8_sales_past_1',
#  'item_3_store_9_sales_past_1',
#  'item_40_store_10_sales_past_1',
#  'item_40_store_1_sales_past_1',
#  'item_40_store_2_sales_past_1',
#  'item_40_store_3_sales_past_1',
#  'item_40_store_4_sales_past_1',
#  'item_40_store_5_sales_past_1',
#  'item_40_store_6_sales_past_1',
#  'item_40_store_7_sales_past_1',
#  'item_40_store_8_sales_past_1',
#  'item_40_store_9_sales_past_1',
#  'item_41_store_10_sales_past_1',
#  'item_41_store_1_sales_past_1',
#  'item_41_store_2_sales_past_1',
#  'item_41_store_3_sales_past_1',
#  'item_41_store_4_sales_past_1',
#  'item_41_store_5_sales_past_1',
#  'item_41_store_6_sales_past_1',
#  'item_41_store_7_sales_past_1',
#  'item_41_store_8_sales_past_1',
#  'item_41_store_9_sales_past_1',
#  'item_42_store_10_sales_past_1',
#  'item_42_store_1_sales_past_1',
#  'item_42_store_2_sales_past_1',
#  'item_42_store_3_sales_past_1',
#  'item_42_store_4_sales_past_1',
#  'item_42_store_5_sales_past_1',
#  'item_42_store_6_sales_past_1',
#  'item_42_store_7_sales_past_1',
#  'item_42_store_8_sales_past_1',
#  'item_42_store_9_sales_past_1',
#  'item_43_store_10_sales_past_1',
#  'item_43_store_1_sales_past_1',
#  'item_43_store_2_sales_past_1',
#  'item_43_store_3_sales_past_1',
#  'item_43_store_4_sales_past_1',
#  'item_43_store_5_sales_past_1',
#  'item_43_store_6_sales_past_1',
#  'item_43_store_7_sales_past_1',
#  'item_43_store_8_sales_past_1',
#  'item_43_store_9_sales_past_1',
#  'item_44_store_10_sales_past_1',
#  'item_44_store_1_sales_past_1',
#  'item_44_store_2_sales_past_1',
#  'item_44_store_3_sales_past_1',
#  'item_44_store_4_sales_past_1',
#  'item_44_store_5_sales_past_1',
#  'item_44_store_6_sales_past_1',
#  'item_44_store_7_sales_past_1',
#  'item_44_store_8_sales_past_1',
#  'item_44_store_9_sales_past_1',
#  'item_45_store_10_sales_past_1',
#  'item_45_store_1_sales_past_1',
#  'item_45_store_2_sales_past_1',
#  'item_45_store_3_sales_past_1',
#  'item_45_store_4_sales_past_1',
#  'item_45_store_5_sales_past_1',
#  'item_45_store_6_sales_past_1',
#  'item_45_store_7_sales_past_1',
#  'item_45_store_8_sales_past_1',
#  'item_45_store_9_sales_past_1',
#  'item_46_store_10_sales_past_1',
#  'item_46_store_1_sales_past_1',
#  'item_46_store_2_sales_past_1',
#  'item_46_store_3_sales_past_1',
#  'item_46_store_4_sales_past_1',
#  'item_46_store_5_sales_past_1',
#  'item_46_store_6_sales_past_1',
#  'item_46_store_7_sales_past_1',
#  'item_46_store_8_sales_past_1',
#  'item_46_store_9_sales_past_1',
#  'item_47_store_10_sales_past_1',
#  'item_47_store_1_sales_past_1',
#  'item_47_store_2_sales_past_1',
#  'item_47_store_3_sales_past_1',
#  'item_47_store_4_sales_past_1',
#  'item_47_store_5_sales_past_1',
#  'item_47_store_6_sales_past_1',
#  'item_47_store_7_sales_past_1',
#  'item_47_store_8_sales_past_1',
#  'item_47_store_9_sales_past_1',
#  'item_48_store_10_sales_past_1',
#  'item_48_store_1_sales_past_1',
#  'item_48_store_2_sales_past_1',
#  'item_48_store_3_sales_past_1',
#  'item_48_store_4_sales_past_1',
#  'item_48_store_5_sales_past_1',
#  'item_48_store_6_sales_past_1',
#  'item_48_store_7_sales_past_1',
#  'item_48_store_8_sales_past_1',
#  'item_48_store_9_sales_past_1',
#  'item_49_store_10_sales_past_1',
#  'item_49_store_1_sales_past_1',
#  'item_49_store_2_sales_past_1',
#  'item_49_store_3_sales_past_1',
#  'item_49_store_4_sales_past_1',
#  'item_49_store_5_sales_past_1',
#  'item_49_store_6_sales_past_1',
#  'item_49_store_7_sales_past_1',
#  'item_49_store_8_sales_past_1',
#  'item_49_store_9_sales_past_1',
#  'item_4_store_10_sales_past_1',
#  'item_4_store_1_sales_past_1',
#  'item_4_store_2_sales_past_1',
#  'item_4_store_3_sales_past_1',
#  'item_4_store_4_sales_past_1',
#  'item_4_store_5_sales_past_1',
#  'item_4_store_6_sales_past_1',
#  'item_4_store_7_sales_past_1',
#  'item_4_store_8_sales_past_1',
#  'item_4_store_9_sales_past_1',
#  'item_50_store_10_sales_past_1',
#  'item_50_store_1_sales_past_1',
#  'item_50_store_2_sales_past_1',
#  'item_50_store_3_sales_past_1',
#  'item_50_store_4_sales_past_1',
#  'item_50_store_5_sales_past_1',
#  'item_50_store_6_sales_past_1',
#  'item_50_store_7_sales_past_1',
#  'item_50_store_8_sales_past_1',
#  'item_50_store_9_sales_past_1',
#  'item_5_store_10_sales_past_1',
#  'item_5_store_1_sales_past_1',
#  'item_5_store_2_sales_past_1',
#  'item_5_store_3_sales_past_1',
#  'item_5_store_4_sales_past_1',
#  'item_5_store_5_sales_past_1',
#  'item_5_store_6_sales_past_1',
#  'item_5_store_7_sales_past_1',
#  'item_5_store_8_sales_past_1',
#  'item_5_store_9_sales_past_1',
#  'item_6_store_10_sales_past_1',
#  'item_6_store_1_sales_past_1',
#  'item_6_store_2_sales_past_1',
#  'item_6_store_3_sales_past_1',
#  'item_6_store_4_sales_past_1',
#  'item_6_store_5_sales_past_1',
#  'item_6_store_6_sales_past_1',
#  'item_6_store_7_sales_past_1',
#  'item_6_store_8_sales_past_1',
#  'item_6_store_9_sales_past_1',
#  'item_7_store_10_sales_past_1',
#  'item_7_store_1_sales_past_1',
#  'item_7_store_2_sales_past_1',
#  'item_7_store_3_sales_past_1',
#  'item_7_store_4_sales_past_1',
#  'item_7_store_5_sales_past_1',
#  'item_7_store_6_sales_past_1',
#  'item_7_store_7_sales_past_1',
#  'item_7_store_8_sales_past_1',
#  'item_7_store_9_sales_past_1',
#  'item_8_store_10_sales_past_1',
#  'item_8_store_1_sales_past_1',
#  'item_8_store_2_sales_past_1',
#  'item_8_store_3_sales_past_1',
#  'item_8_store_4_sales_past_1',
#  'item_8_store_5_sales_past_1',
#  'item_8_store_6_sales_past_1',
#  'item_8_store_7_sales_past_1',
#  'item_8_store_8_sales_past_1',
#  'item_8_store_9_sales_past_1',
#  'item_9_store_10_sales_past_1',
#  'item_9_store_1_sales_past_1',
#  'item_9_store_2_sales_past_1',
#  'item_9_store_3_sales_past_1',
#  'item_9_store_4_sales_past_1',
#  'item_9_store_5_sales_past_1',
#  'item_9_store_6_sales_past_1',
#  'item_9_store_7_sales_past_1',
#  'item_9_store_8_sales_past_1',
#  'item_9_store_9_sales_past_1',
#  'item_10_store_10_sales',
#  'item_10_store_1_sales',
#  'item_10_store_2_sales',
#  'item_10_store_3_sales',
#  'item_10_store_4_sales',
#  'item_10_store_5_sales',
#  'item_10_store_6_sales',
#  'item_10_store_7_sales',
#  'item_10_store_8_sales',
#  'item_10_store_9_sales',
#  'item_11_store_10_sales',
#  'item_11_store_1_sales',
#  'item_11_store_2_sales',
#  'item_11_store_3_sales',
#  'item_11_store_4_sales',
#  'item_11_store_5_sales',
#  'item_11_store_6_sales',
#  'item_11_store_7_sales',
#  'item_11_store_8_sales',
#  'item_11_store_9_sales',
#  'item_12_store_10_sales',
#  'item_12_store_1_sales',
#  'item_12_store_2_sales',
#  'item_12_store_3_sales',
#  'item_12_store_4_sales',
#  'item_12_store_5_sales',
#  'item_12_store_6_sales',
#  'item_12_store_7_sales',
#  'item_12_store_8_sales',
#  'item_12_store_9_sales',
#  'item_13_store_10_sales',
#  'item_13_store_1_sales',
#  'item_13_store_2_sales',
#  'item_13_store_3_sales',
#  'item_13_store_4_sales',
#  'item_13_store_5_sales',
#  'item_13_store_6_sales',
#  'item_13_store_7_sales',
#  'item_13_store_8_sales',
#  'item_13_store_9_sales',
#  'item_14_store_10_sales',
#  'item_14_store_1_sales',
#  'item_14_store_2_sales',
#  'item_14_store_3_sales',
#  'item_14_store_4_sales',
#  'item_14_store_5_sales',
#  'item_14_store_6_sales',
#  'item_14_store_7_sales',
#  'item_14_store_8_sales',
#  'item_14_store_9_sales',
#  'item_15_store_10_sales',
#  'item_15_store_1_sales',
#  'item_15_store_2_sales',
#  'item_15_store_3_sales',
#  'item_15_store_4_sales',
#  'item_15_store_5_sales',
#  'item_15_store_6_sales',
#  'item_15_store_7_sales',
#  'item_15_store_8_sales',
#  'item_15_store_9_sales',
#  'item_16_store_10_sales',
#  'item_16_store_1_sales',
#  'item_16_store_2_sales',
#  'item_16_store_3_sales',
#  'item_16_store_4_sales',
#  'item_16_store_5_sales',
#  'item_16_store_6_sales',
#  'item_16_store_7_sales',
#  'item_16_store_8_sales',
#  'item_16_store_9_sales',
#  'item_17_store_10_sales',
#  'item_17_store_1_sales',
#  'item_17_store_2_sales',
#  'item_17_store_3_sales',
#  'item_17_store_4_sales',
#  'item_17_store_5_sales',
#  'item_17_store_6_sales',
#  'item_17_store_7_sales',
#  'item_17_store_8_sales',
#  'item_17_store_9_sales',
#  'item_18_store_10_sales',
#  'item_18_store_1_sales',
#  'item_18_store_2_sales',
#  'item_18_store_3_sales',
#  'item_18_store_4_sales',
#  'item_18_store_5_sales',
#  'item_18_store_6_sales',
#  'item_18_store_7_sales',
#  'item_18_store_8_sales',
#  'item_18_store_9_sales',
#  'item_19_store_10_sales',
#  'item_19_store_1_sales',
#  'item_19_store_2_sales',
#  'item_19_store_3_sales',
#  'item_19_store_4_sales',
#  'item_19_store_5_sales',
#  'item_19_store_6_sales',
#  'item_19_store_7_sales',
#  'item_19_store_8_sales',
#  'item_19_store_9_sales',
#  'item_1_store_10_sales',
#  'item_1_store_1_sales',
#  'item_1_store_2_sales',
#  'item_1_store_3_sales',
#  'item_1_store_4_sales',
#  'item_1_store_5_sales',
#  'item_1_store_6_sales',
#  'item_1_store_7_sales',
#  'item_1_store_8_sales',
#  'item_1_store_9_sales',
#  'item_20_store_10_sales',
#  'item_20_store_1_sales',
#  'item_20_store_2_sales',
#  'item_20_store_3_sales',
#  'item_20_store_4_sales',
#  'item_20_store_5_sales',
#  'item_20_store_6_sales',
#  'item_20_store_7_sales',
#  'item_20_store_8_sales',
#  'item_20_store_9_sales',
#  'item_21_store_10_sales',
#  'item_21_store_1_sales',
#  'item_21_store_2_sales',
#  'item_21_store_3_sales',
#  'item_21_store_4_sales',
#  'item_21_store_5_sales',
#  'item_21_store_6_sales',
#  'item_21_store_7_sales',
#  'item_21_store_8_sales',
#  'item_21_store_9_sales',
#  'item_22_store_10_sales',
#  'item_22_store_1_sales',
#  'item_22_store_2_sales',
#  'item_22_store_3_sales',
#  'item_22_store_4_sales',
#  'item_22_store_5_sales',
#  'item_22_store_6_sales',
#  'item_22_store_7_sales',
#  'item_22_store_8_sales',
#  'item_22_store_9_sales',
#  'item_23_store_10_sales',
#  'item_23_store_1_sales',
#  'item_23_store_2_sales',
#  'item_23_store_3_sales',
#  'item_23_store_4_sales',
#  'item_23_store_5_sales',
#  'item_23_store_6_sales',
#  'item_23_store_7_sales',
#  'item_23_store_8_sales',
#  'item_23_store_9_sales',
#  'item_24_store_10_sales',
#  'item_24_store_1_sales',
#  'item_24_store_2_sales',
#  'item_24_store_3_sales',
#  'item_24_store_4_sales',
#  'item_24_store_5_sales',
#  'item_24_store_6_sales',
#  'item_24_store_7_sales',
#  'item_24_store_8_sales',
#  'item_24_store_9_sales',
#  'item_25_store_10_sales',
#  'item_25_store_1_sales',
#  'item_25_store_2_sales',
#  'item_25_store_3_sales',
#  'item_25_store_4_sales',
#  'item_25_store_5_sales',
#  'item_25_store_6_sales',
#  'item_25_store_7_sales',
#  'item_25_store_8_sales',
#  'item_25_store_9_sales',
#  'item_26_store_10_sales',
#  'item_26_store_1_sales',
#  'item_26_store_2_sales',
#  'item_26_store_3_sales',
#  'item_26_store_4_sales',
#  'item_26_store_5_sales',
#  'item_26_store_6_sales',
#  'item_26_store_7_sales',
#  'item_26_store_8_sales',
#  'item_26_store_9_sales',
#  'item_27_store_10_sales',
#  'item_27_store_1_sales',
#  'item_27_store_2_sales',
#  'item_27_store_3_sales',
#  'item_27_store_4_sales',
#  'item_27_store_5_sales',
#  'item_27_store_6_sales',
#  'item_27_store_7_sales',
#  'item_27_store_8_sales',
#  'item_27_store_9_sales',
#  'item_28_store_10_sales',
#  'item_28_store_1_sales',
#  'item_28_store_2_sales',
#  'item_28_store_3_sales',
#  'item_28_store_4_sales',
#  'item_28_store_5_sales',
#  'item_28_store_6_sales',
#  'item_28_store_7_sales',
#  'item_28_store_8_sales',
#  'item_28_store_9_sales',
#  'item_29_store_10_sales',
#  'item_29_store_1_sales',
#  'item_29_store_2_sales',
#  'item_29_store_3_sales',
#  'item_29_store_4_sales',
#  'item_29_store_5_sales',
#  'item_29_store_6_sales',
#  'item_29_store_7_sales',
#  'item_29_store_8_sales',
#  'item_29_store_9_sales',
#  'item_2_store_10_sales',
#  'item_2_store_1_sales',
#  'item_2_store_2_sales',
#  'item_2_store_3_sales',
#  'item_2_store_4_sales',
#  'item_2_store_5_sales',
#  'item_2_store_6_sales',
#  'item_2_store_7_sales',
#  'item_2_store_8_sales',
#  'item_2_store_9_sales',
#  'item_30_store_10_sales',
#  'item_30_store_1_sales',
#  'item_30_store_2_sales',
#  'item_30_store_3_sales',
#  'item_30_store_4_sales',
#  'item_30_store_5_sales',
#  'item_30_store_6_sales',
#  'item_30_store_7_sales',
#  'item_30_store_8_sales',
#  'item_30_store_9_sales',
#  'item_31_store_10_sales',
#  'item_31_store_1_sales',
#  'item_31_store_2_sales',
#  'item_31_store_3_sales',
#  'item_31_store_4_sales',
#  'item_31_store_5_sales',
#  'item_31_store_6_sales',
#  'item_31_store_7_sales',
#  'item_31_store_8_sales',
#  'item_31_store_9_sales',
#  'item_32_store_10_sales',
#  'item_32_store_1_sales',
#  'item_32_store_2_sales',
#  'item_32_store_3_sales',
#  'item_32_store_4_sales',
#  'item_32_store_5_sales',
#  'item_32_store_6_sales',
#  'item_32_store_7_sales',
#  'item_32_store_8_sales',
#  'item_32_store_9_sales',
#  'item_33_store_10_sales',
#  'item_33_store_1_sales',
#  'item_33_store_2_sales',
#  'item_33_store_3_sales',
#  'item_33_store_4_sales',
#  'item_33_store_5_sales',
#  'item_33_store_6_sales',
#  'item_33_store_7_sales',
#  'item_33_store_8_sales',
#  'item_33_store_9_sales',
#  'item_34_store_10_sales',
#  'item_34_store_1_sales',
#  'item_34_store_2_sales',
#  'item_34_store_3_sales',
#  'item_34_store_4_sales',
#  'item_34_store_5_sales',
#  'item_34_store_6_sales',
#  'item_34_store_7_sales',
#  'item_34_store_8_sales',
#  'item_34_store_9_sales',
#  'item_35_store_10_sales',
#  'item_35_store_1_sales',
#  'item_35_store_2_sales',
#  'item_35_store_3_sales',
#  'item_35_store_4_sales',
#  'item_35_store_5_sales',
#  'item_35_store_6_sales',
#  'item_35_store_7_sales',
#  'item_35_store_8_sales',
#  'item_35_store_9_sales',
#  'item_36_store_10_sales',
#  'item_36_store_1_sales',
#  'item_36_store_2_sales',
#  'item_36_store_3_sales',
#  'item_36_store_4_sales',
#  'item_36_store_5_sales',
#  'item_36_store_6_sales',
#  'item_36_store_7_sales',
#  'item_36_store_8_sales',
#  'item_36_store_9_sales',
#  'item_37_store_10_sales',
#  'item_37_store_1_sales',
#  'item_37_store_2_sales',
#  'item_37_store_3_sales',
#  'item_37_store_4_sales',
#  'item_37_store_5_sales',
#  'item_37_store_6_sales',
#  'item_37_store_7_sales',
#  'item_37_store_8_sales',
#  'item_37_store_9_sales',
#  'item_38_store_10_sales',
#  'item_38_store_1_sales',
#  'item_38_store_2_sales',
#  'item_38_store_3_sales',
#  'item_38_store_4_sales',
#  'item_38_store_5_sales',
#  'item_38_store_6_sales',
#  'item_38_store_7_sales',
#  'item_38_store_8_sales',
#  'item_38_store_9_sales',
#  'item_39_store_10_sales',
#  'item_39_store_1_sales',
#  'item_39_store_2_sales',
#  'item_39_store_3_sales',
#  'item_39_store_4_sales',
#  'item_39_store_5_sales',
#  'item_39_store_6_sales',
#  'item_39_store_7_sales',
#  'item_39_store_8_sales',
#  'item_39_store_9_sales',
#  'item_3_store_10_sales',
#  'item_3_store_1_sales',
#  'item_3_store_2_sales',
#  'item_3_store_3_sales',
#  'item_3_store_4_sales',
#  'item_3_store_5_sales',
#  'item_3_store_6_sales',
#  'item_3_store_7_sales',
#  'item_3_store_8_sales',
#  'item_3_store_9_sales',
#  'item_40_store_10_sales',
#  'item_40_store_1_sales',
#  'item_40_store_2_sales',
#  'item_40_store_3_sales',
#  'item_40_store_4_sales',
#  'item_40_store_5_sales',
#  'item_40_store_6_sales',
#  'item_40_store_7_sales',
#  'item_40_store_8_sales',
#  'item_40_store_9_sales',
#  'item_41_store_10_sales',
#  'item_41_store_1_sales',
#  'item_41_store_2_sales',
#  'item_41_store_3_sales',
#  'item_41_store_4_sales',
#  'item_41_store_5_sales',
#  'item_41_store_6_sales',
#  'item_41_store_7_sales',
#  'item_41_store_8_sales',
#  'item_41_store_9_sales',
#  'item_42_store_10_sales',
#  'item_42_store_1_sales',
#  'item_42_store_2_sales',
#  'item_42_store_3_sales',
#  'item_42_store_4_sales',
#  'item_42_store_5_sales',
#  'item_42_store_6_sales',
#  'item_42_store_7_sales',
#  'item_42_store_8_sales',
#  'item_42_store_9_sales',
#  'item_43_store_10_sales',
#  'item_43_store_1_sales',
#  'item_43_store_2_sales',
#  'item_43_store_3_sales',
#  'item_43_store_4_sales',
#  'item_43_store_5_sales',
#  'item_43_store_6_sales',
#  'item_43_store_7_sales',
#  'item_43_store_8_sales',
#  'item_43_store_9_sales',
#  'item_44_store_10_sales',
#  'item_44_store_1_sales',
#  'item_44_store_2_sales',
#  'item_44_store_3_sales',
#  'item_44_store_4_sales',
#  'item_44_store_5_sales',
#  'item_44_store_6_sales',
#  'item_44_store_7_sales',
#  'item_44_store_8_sales',
#  'item_44_store_9_sales',
#  'item_45_store_10_sales',
#  'item_45_store_1_sales',
#  'item_45_store_2_sales',
#  'item_45_store_3_sales',
#  'item_45_store_4_sales',
#  'item_45_store_5_sales',
#  'item_45_store_6_sales',
#  'item_45_store_7_sales',
#  'item_45_store_8_sales',
#  'item_45_store_9_sales',
#  'item_46_store_10_sales',
#  'item_46_store_1_sales',
#  'item_46_store_2_sales',
#  'item_46_store_3_sales',
#  'item_46_store_4_sales',
#  'item_46_store_5_sales',
#  'item_46_store_6_sales',
#  'item_46_store_7_sales',
#  'item_46_store_8_sales',
#  'item_46_store_9_sales',
#  'item_47_store_10_sales',
#  'item_47_store_1_sales',
#  'item_47_store_2_sales',
#  'item_47_store_3_sales',
#  'item_47_store_4_sales',
#  'item_47_store_5_sales',
#  'item_47_store_6_sales',
#  'item_47_store_7_sales',
#  'item_47_store_8_sales',
#  'item_47_store_9_sales',
#  'item_48_store_10_sales',
#  'item_48_store_1_sales',
#  'item_48_store_2_sales',
#  'item_48_store_3_sales',
#  'item_48_store_4_sales',
#  'item_48_store_5_sales',
#  'item_48_store_6_sales',
#  'item_48_store_7_sales',
#  'item_48_store_8_sales',
#  'item_48_store_9_sales',
#  'item_49_store_10_sales',
#  'item_49_store_1_sales',
#  'item_49_store_2_sales',
#  'item_49_store_3_sales',
#  'item_49_store_4_sales',
#  'item_49_store_5_sales',
#  'item_49_store_6_sales',
#  'item_49_store_7_sales',
#  'item_49_store_8_sales',
#  'item_49_store_9_sales',
#  'item_4_store_10_sales',
#  'item_4_store_1_sales',
#  'item_4_store_2_sales',
#  'item_4_store_3_sales',
#  'item_4_store_4_sales',
#  'item_4_store_5_sales',
#  'item_4_store_6_sales',
#  'item_4_store_7_sales',
#  'item_4_store_8_sales',
#  'item_4_store_9_sales',
#  'item_50_store_10_sales',
#  'item_50_store_1_sales',
#  'item_50_store_2_sales',
#  'item_50_store_3_sales',
#  'item_50_store_4_sales',
#  'item_50_store_5_sales',
#  'item_50_store_6_sales',
#  'item_50_store_7_sales',
#  'item_50_store_8_sales',
#  'item_50_store_9_sales',
#  'item_5_store_10_sales',
#  'item_5_store_1_sales',
#  'item_5_store_2_sales',
#  'item_5_store_3_sales',
#  'item_5_store_4_sales',
#  'item_5_store_5_sales',
#  'item_5_store_6_sales',
#  'item_5_store_7_sales',
#  'item_5_store_8_sales',
#  'item_5_store_9_sales',
#  'item_6_store_10_sales',
#  'item_6_store_1_sales',
#  'item_6_store_2_sales',
#  'item_6_store_3_sales',
#  'item_6_store_4_sales',
#  'item_6_store_5_sales',
#  'item_6_store_6_sales',
#  'item_6_store_7_sales',
#  'item_6_store_8_sales',
#  'item_6_store_9_sales',
#  'item_7_store_10_sales',
#  'item_7_store_1_sales',
#  'item_7_store_2_sales',
#  'item_7_store_3_sales',
#  'item_7_store_4_sales',
#  'item_7_store_5_sales',
#  'item_7_store_6_sales',
#  'item_7_store_7_sales',
#  'item_7_store_8_sales',
#  'item_7_store_9_sales',
#  ...]

# %%
df_total = df_total.reindex(columns=new_cols)

# %%
df_total.head()
# Out:
#             weekday_0  weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# date
# 2013-01-02          0          0          1          0          0          0
# 2013-01-03          0          0          0          1          0          0
# 2013-01-04          0          0          0          0          1          0
# 2013-01-05          0          0          0          0          0          1
# 2013-01-06          0          0          0          0          0          0
#
#                     ...           item_9_store_4_sales  item_9_store_5_sales  \
# date                ...
# 2013-01-02          ...                           21.0                  20.0
# 2013-01-03          ...                           25.0                  15.0
# 2013-01-04          ...                           37.0                  20.0
# 2013-01-05          ...                           37.0                  23.0
# 2013-01-06          ...                           37.0                  29.0
#
#             item_9_store_6_sales  item_9_store_7_sales  item_9_store_8_sales  \
# date
# 2013-01-02                  17.0                  20.0                  28.0
# 2013-01-03                  28.0                  18.0                  31.0
# 2013-01-04                  33.0                  24.0                  46.0
# 2013-01-05                  27.0                  14.0                  35.0
# 2013-01-06                  20.0                  24.0                  34.0
#
#             item_9_store_9_sales
# date
# 2013-01-02                  36.0
# 2013-01-03                  25.0
# 2013-01-04                  31.0
# 2013-01-05                  30.0
# 2013-01-06                  35.0
#
# [5 rows x 1020 columns]

# %%
# assert df_total.isna().any().any() == False
assert df_total.isnull().any().any() == False

# %% [markdown]
# ### Scaling
# With combined datasets and shifted sales, we can now correctly min-max scale all data.
# This is necessary for neural networks to work as intended.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
scaler = MinMaxScaler(feature_range=(0,1))
cols_to_scale = [col for col in df_total.columns if 'weekday' not in col and 'month' not in col]
scaled_cols = scaler.fit_transform(df_total[cols_to_scale])
df_total[cols_to_scale] = scaled_cols

# %%
df_total.head()
# Out:
#             weekday_0  weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# date
# 2013-01-02          0          0          1          0          0          0
# 2013-01-03          0          0          0          1          0          0
# 2013-01-04          0          0          0          0          1          0
# 2013-01-05          0          0          0          0          0          1
# 2013-01-06          0          0          0          0          0          0
#
#                     ...           item_9_store_4_sales  item_9_store_5_sales  \
# date                ...
# 2013-01-02          ...                       0.189189              0.238095
# 2013-01-03          ...                       0.225225              0.178571
# 2013-01-04          ...                       0.333333              0.238095
# 2013-01-05          ...                       0.333333              0.273810
# 2013-01-06          ...                       0.333333              0.345238
#
#             item_9_store_6_sales  item_9_store_7_sales  item_9_store_8_sales  \
# date
# 2013-01-02              0.209877              0.256410              0.208955
# 2013-01-03              0.345679              0.230769              0.231343
# 2013-01-04              0.407407              0.307692              0.343284
# 2013-01-05              0.333333              0.179487              0.261194
# 2013-01-06              0.246914              0.307692              0.253731
#
#             item_9_store_9_sales
# date
# 2013-01-02              0.327273
# 2013-01-03              0.227273
# 2013-01-04              0.281818
# 2013-01-05              0.272727
# 2013-01-06              0.318182
#
# [5 rows x 1020 columns]

# %% [markdown]
# ### Split back to train and test set

# %%
df_train = df_total[df_total['is_test'] == False].drop('is_test', axis=1)
df_test = df_total[df_total['is_test'] == True].drop('is_test', axis=1)

# %% [markdown]
# ## Training models
# First, we need to separate training data into input and target vectors, and separate part of training data as validation data for our models.

# %%
X_cols_stacked = [col for col in df_train.columns if '_past_' in col]
X_cols_caldata = [col for col in df_train.columns if 'weekday_' in col or 'month_' in col or 'year' in col]
X_cols = X_cols_stacked + X_cols_caldata

X = df_train[X_cols]

# %%
X_cols
# Out:
# ['item_10_store_10_sales_past_1',
#  'item_10_store_1_sales_past_1',
#  'item_10_store_2_sales_past_1',
#  'item_10_store_3_sales_past_1',
#  'item_10_store_4_sales_past_1',
#  'item_10_store_5_sales_past_1',
#  'item_10_store_6_sales_past_1',
#  'item_10_store_7_sales_past_1',
#  'item_10_store_8_sales_past_1',
#  'item_10_store_9_sales_past_1',
#  'item_11_store_10_sales_past_1',
#  'item_11_store_1_sales_past_1',
#  'item_11_store_2_sales_past_1',
#  'item_11_store_3_sales_past_1',
#  'item_11_store_4_sales_past_1',
#  'item_11_store_5_sales_past_1',
#  'item_11_store_6_sales_past_1',
#  'item_11_store_7_sales_past_1',
#  'item_11_store_8_sales_past_1',
#  'item_11_store_9_sales_past_1',
#  'item_12_store_10_sales_past_1',
#  'item_12_store_1_sales_past_1',
#  'item_12_store_2_sales_past_1',
#  'item_12_store_3_sales_past_1',
#  'item_12_store_4_sales_past_1',
#  'item_12_store_5_sales_past_1',
#  'item_12_store_6_sales_past_1',
#  'item_12_store_7_sales_past_1',
#  'item_12_store_8_sales_past_1',
#  'item_12_store_9_sales_past_1',
#  'item_13_store_10_sales_past_1',
#  'item_13_store_1_sales_past_1',
#  'item_13_store_2_sales_past_1',
#  'item_13_store_3_sales_past_1',
#  'item_13_store_4_sales_past_1',
#  'item_13_store_5_sales_past_1',
#  'item_13_store_6_sales_past_1',
#  'item_13_store_7_sales_past_1',
#  'item_13_store_8_sales_past_1',
#  'item_13_store_9_sales_past_1',
#  'item_14_store_10_sales_past_1',
#  'item_14_store_1_sales_past_1',
#  'item_14_store_2_sales_past_1',
#  'item_14_store_3_sales_past_1',
#  'item_14_store_4_sales_past_1',
#  'item_14_store_5_sales_past_1',
#  'item_14_store_6_sales_past_1',
#  'item_14_store_7_sales_past_1',
#  'item_14_store_8_sales_past_1',
#  'item_14_store_9_sales_past_1',
#  'item_15_store_10_sales_past_1',
#  'item_15_store_1_sales_past_1',
#  'item_15_store_2_sales_past_1',
#  'item_15_store_3_sales_past_1',
#  'item_15_store_4_sales_past_1',
#  'item_15_store_5_sales_past_1',
#  'item_15_store_6_sales_past_1',
#  'item_15_store_7_sales_past_1',
#  'item_15_store_8_sales_past_1',
#  'item_15_store_9_sales_past_1',
#  'item_16_store_10_sales_past_1',
#  'item_16_store_1_sales_past_1',
#  'item_16_store_2_sales_past_1',
#  'item_16_store_3_sales_past_1',
#  'item_16_store_4_sales_past_1',
#  'item_16_store_5_sales_past_1',
#  'item_16_store_6_sales_past_1',
#  'item_16_store_7_sales_past_1',
#  'item_16_store_8_sales_past_1',
#  'item_16_store_9_sales_past_1',
#  'item_17_store_10_sales_past_1',
#  'item_17_store_1_sales_past_1',
#  'item_17_store_2_sales_past_1',
#  'item_17_store_3_sales_past_1',
#  'item_17_store_4_sales_past_1',
#  'item_17_store_5_sales_past_1',
#  'item_17_store_6_sales_past_1',
#  'item_17_store_7_sales_past_1',
#  'item_17_store_8_sales_past_1',
#  'item_17_store_9_sales_past_1',
#  'item_18_store_10_sales_past_1',
#  'item_18_store_1_sales_past_1',
#  'item_18_store_2_sales_past_1',
#  'item_18_store_3_sales_past_1',
#  'item_18_store_4_sales_past_1',
#  'item_18_store_5_sales_past_1',
#  'item_18_store_6_sales_past_1',
#  'item_18_store_7_sales_past_1',
#  'item_18_store_8_sales_past_1',
#  'item_18_store_9_sales_past_1',
#  'item_19_store_10_sales_past_1',
#  'item_19_store_1_sales_past_1',
#  'item_19_store_2_sales_past_1',
#  'item_19_store_3_sales_past_1',
#  'item_19_store_4_sales_past_1',
#  'item_19_store_5_sales_past_1',
#  'item_19_store_6_sales_past_1',
#  'item_19_store_7_sales_past_1',
#  'item_19_store_8_sales_past_1',
#  'item_19_store_9_sales_past_1',
#  'item_1_store_10_sales_past_1',
#  'item_1_store_1_sales_past_1',
#  'item_1_store_2_sales_past_1',
#  'item_1_store_3_sales_past_1',
#  'item_1_store_4_sales_past_1',
#  'item_1_store_5_sales_past_1',
#  'item_1_store_6_sales_past_1',
#  'item_1_store_7_sales_past_1',
#  'item_1_store_8_sales_past_1',
#  'item_1_store_9_sales_past_1',
#  'item_20_store_10_sales_past_1',
#  'item_20_store_1_sales_past_1',
#  'item_20_store_2_sales_past_1',
#  'item_20_store_3_sales_past_1',
#  'item_20_store_4_sales_past_1',
#  'item_20_store_5_sales_past_1',
#  'item_20_store_6_sales_past_1',
#  'item_20_store_7_sales_past_1',
#  'item_20_store_8_sales_past_1',
#  'item_20_store_9_sales_past_1',
#  'item_21_store_10_sales_past_1',
#  'item_21_store_1_sales_past_1',
#  'item_21_store_2_sales_past_1',
#  'item_21_store_3_sales_past_1',
#  'item_21_store_4_sales_past_1',
#  'item_21_store_5_sales_past_1',
#  'item_21_store_6_sales_past_1',
#  'item_21_store_7_sales_past_1',
#  'item_21_store_8_sales_past_1',
#  'item_21_store_9_sales_past_1',
#  'item_22_store_10_sales_past_1',
#  'item_22_store_1_sales_past_1',
#  'item_22_store_2_sales_past_1',
#  'item_22_store_3_sales_past_1',
#  'item_22_store_4_sales_past_1',
#  'item_22_store_5_sales_past_1',
#  'item_22_store_6_sales_past_1',
#  'item_22_store_7_sales_past_1',
#  'item_22_store_8_sales_past_1',
#  'item_22_store_9_sales_past_1',
#  'item_23_store_10_sales_past_1',
#  'item_23_store_1_sales_past_1',
#  'item_23_store_2_sales_past_1',
#  'item_23_store_3_sales_past_1',
#  'item_23_store_4_sales_past_1',
#  'item_23_store_5_sales_past_1',
#  'item_23_store_6_sales_past_1',
#  'item_23_store_7_sales_past_1',
#  'item_23_store_8_sales_past_1',
#  'item_23_store_9_sales_past_1',
#  'item_24_store_10_sales_past_1',
#  'item_24_store_1_sales_past_1',
#  'item_24_store_2_sales_past_1',
#  'item_24_store_3_sales_past_1',
#  'item_24_store_4_sales_past_1',
#  'item_24_store_5_sales_past_1',
#  'item_24_store_6_sales_past_1',
#  'item_24_store_7_sales_past_1',
#  'item_24_store_8_sales_past_1',
#  'item_24_store_9_sales_past_1',
#  'item_25_store_10_sales_past_1',
#  'item_25_store_1_sales_past_1',
#  'item_25_store_2_sales_past_1',
#  'item_25_store_3_sales_past_1',
#  'item_25_store_4_sales_past_1',
#  'item_25_store_5_sales_past_1',
#  'item_25_store_6_sales_past_1',
#  'item_25_store_7_sales_past_1',
#  'item_25_store_8_sales_past_1',
#  'item_25_store_9_sales_past_1',
#  'item_26_store_10_sales_past_1',
#  'item_26_store_1_sales_past_1',
#  'item_26_store_2_sales_past_1',
#  'item_26_store_3_sales_past_1',
#  'item_26_store_4_sales_past_1',
#  'item_26_store_5_sales_past_1',
#  'item_26_store_6_sales_past_1',
#  'item_26_store_7_sales_past_1',
#  'item_26_store_8_sales_past_1',
#  'item_26_store_9_sales_past_1',
#  'item_27_store_10_sales_past_1',
#  'item_27_store_1_sales_past_1',
#  'item_27_store_2_sales_past_1',
#  'item_27_store_3_sales_past_1',
#  'item_27_store_4_sales_past_1',
#  'item_27_store_5_sales_past_1',
#  'item_27_store_6_sales_past_1',
#  'item_27_store_7_sales_past_1',
#  'item_27_store_8_sales_past_1',
#  'item_27_store_9_sales_past_1',
#  'item_28_store_10_sales_past_1',
#  'item_28_store_1_sales_past_1',
#  'item_28_store_2_sales_past_1',
#  'item_28_store_3_sales_past_1',
#  'item_28_store_4_sales_past_1',
#  'item_28_store_5_sales_past_1',
#  'item_28_store_6_sales_past_1',
#  'item_28_store_7_sales_past_1',
#  'item_28_store_8_sales_past_1',
#  'item_28_store_9_sales_past_1',
#  'item_29_store_10_sales_past_1',
#  'item_29_store_1_sales_past_1',
#  'item_29_store_2_sales_past_1',
#  'item_29_store_3_sales_past_1',
#  'item_29_store_4_sales_past_1',
#  'item_29_store_5_sales_past_1',
#  'item_29_store_6_sales_past_1',
#  'item_29_store_7_sales_past_1',
#  'item_29_store_8_sales_past_1',
#  'item_29_store_9_sales_past_1',
#  'item_2_store_10_sales_past_1',
#  'item_2_store_1_sales_past_1',
#  'item_2_store_2_sales_past_1',
#  'item_2_store_3_sales_past_1',
#  'item_2_store_4_sales_past_1',
#  'item_2_store_5_sales_past_1',
#  'item_2_store_6_sales_past_1',
#  'item_2_store_7_sales_past_1',
#  'item_2_store_8_sales_past_1',
#  'item_2_store_9_sales_past_1',
#  'item_30_store_10_sales_past_1',
#  'item_30_store_1_sales_past_1',
#  'item_30_store_2_sales_past_1',
#  'item_30_store_3_sales_past_1',
#  'item_30_store_4_sales_past_1',
#  'item_30_store_5_sales_past_1',
#  'item_30_store_6_sales_past_1',
#  'item_30_store_7_sales_past_1',
#  'item_30_store_8_sales_past_1',
#  'item_30_store_9_sales_past_1',
#  'item_31_store_10_sales_past_1',
#  'item_31_store_1_sales_past_1',
#  'item_31_store_2_sales_past_1',
#  'item_31_store_3_sales_past_1',
#  'item_31_store_4_sales_past_1',
#  'item_31_store_5_sales_past_1',
#  'item_31_store_6_sales_past_1',
#  'item_31_store_7_sales_past_1',
#  'item_31_store_8_sales_past_1',
#  'item_31_store_9_sales_past_1',
#  'item_32_store_10_sales_past_1',
#  'item_32_store_1_sales_past_1',
#  'item_32_store_2_sales_past_1',
#  'item_32_store_3_sales_past_1',
#  'item_32_store_4_sales_past_1',
#  'item_32_store_5_sales_past_1',
#  'item_32_store_6_sales_past_1',
#  'item_32_store_7_sales_past_1',
#  'item_32_store_8_sales_past_1',
#  'item_32_store_9_sales_past_1',
#  'item_33_store_10_sales_past_1',
#  'item_33_store_1_sales_past_1',
#  'item_33_store_2_sales_past_1',
#  'item_33_store_3_sales_past_1',
#  'item_33_store_4_sales_past_1',
#  'item_33_store_5_sales_past_1',
#  'item_33_store_6_sales_past_1',
#  'item_33_store_7_sales_past_1',
#  'item_33_store_8_sales_past_1',
#  'item_33_store_9_sales_past_1',
#  'item_34_store_10_sales_past_1',
#  'item_34_store_1_sales_past_1',
#  'item_34_store_2_sales_past_1',
#  'item_34_store_3_sales_past_1',
#  'item_34_store_4_sales_past_1',
#  'item_34_store_5_sales_past_1',
#  'item_34_store_6_sales_past_1',
#  'item_34_store_7_sales_past_1',
#  'item_34_store_8_sales_past_1',
#  'item_34_store_9_sales_past_1',
#  'item_35_store_10_sales_past_1',
#  'item_35_store_1_sales_past_1',
#  'item_35_store_2_sales_past_1',
#  'item_35_store_3_sales_past_1',
#  'item_35_store_4_sales_past_1',
#  'item_35_store_5_sales_past_1',
#  'item_35_store_6_sales_past_1',
#  'item_35_store_7_sales_past_1',
#  'item_35_store_8_sales_past_1',
#  'item_35_store_9_sales_past_1',
#  'item_36_store_10_sales_past_1',
#  'item_36_store_1_sales_past_1',
#  'item_36_store_2_sales_past_1',
#  'item_36_store_3_sales_past_1',
#  'item_36_store_4_sales_past_1',
#  'item_36_store_5_sales_past_1',
#  'item_36_store_6_sales_past_1',
#  'item_36_store_7_sales_past_1',
#  'item_36_store_8_sales_past_1',
#  'item_36_store_9_sales_past_1',
#  'item_37_store_10_sales_past_1',
#  'item_37_store_1_sales_past_1',
#  'item_37_store_2_sales_past_1',
#  'item_37_store_3_sales_past_1',
#  'item_37_store_4_sales_past_1',
#  'item_37_store_5_sales_past_1',
#  'item_37_store_6_sales_past_1',
#  'item_37_store_7_sales_past_1',
#  'item_37_store_8_sales_past_1',
#  'item_37_store_9_sales_past_1',
#  'item_38_store_10_sales_past_1',
#  'item_38_store_1_sales_past_1',
#  'item_38_store_2_sales_past_1',
#  'item_38_store_3_sales_past_1',
#  'item_38_store_4_sales_past_1',
#  'item_38_store_5_sales_past_1',
#  'item_38_store_6_sales_past_1',
#  'item_38_store_7_sales_past_1',
#  'item_38_store_8_sales_past_1',
#  'item_38_store_9_sales_past_1',
#  'item_39_store_10_sales_past_1',
#  'item_39_store_1_sales_past_1',
#  'item_39_store_2_sales_past_1',
#  'item_39_store_3_sales_past_1',
#  'item_39_store_4_sales_past_1',
#  'item_39_store_5_sales_past_1',
#  'item_39_store_6_sales_past_1',
#  'item_39_store_7_sales_past_1',
#  'item_39_store_8_sales_past_1',
#  'item_39_store_9_sales_past_1',
#  'item_3_store_10_sales_past_1',
#  'item_3_store_1_sales_past_1',
#  'item_3_store_2_sales_past_1',
#  'item_3_store_3_sales_past_1',
#  'item_3_store_4_sales_past_1',
#  'item_3_store_5_sales_past_1',
#  'item_3_store_6_sales_past_1',
#  'item_3_store_7_sales_past_1',
#  'item_3_store_8_sales_past_1',
#  'item_3_store_9_sales_past_1',
#  'item_40_store_10_sales_past_1',
#  'item_40_store_1_sales_past_1',
#  'item_40_store_2_sales_past_1',
#  'item_40_store_3_sales_past_1',
#  'item_40_store_4_sales_past_1',
#  'item_40_store_5_sales_past_1',
#  'item_40_store_6_sales_past_1',
#  'item_40_store_7_sales_past_1',
#  'item_40_store_8_sales_past_1',
#  'item_40_store_9_sales_past_1',
#  'item_41_store_10_sales_past_1',
#  'item_41_store_1_sales_past_1',
#  'item_41_store_2_sales_past_1',
#  'item_41_store_3_sales_past_1',
#  'item_41_store_4_sales_past_1',
#  'item_41_store_5_sales_past_1',
#  'item_41_store_6_sales_past_1',
#  'item_41_store_7_sales_past_1',
#  'item_41_store_8_sales_past_1',
#  'item_41_store_9_sales_past_1',
#  'item_42_store_10_sales_past_1',
#  'item_42_store_1_sales_past_1',
#  'item_42_store_2_sales_past_1',
#  'item_42_store_3_sales_past_1',
#  'item_42_store_4_sales_past_1',
#  'item_42_store_5_sales_past_1',
#  'item_42_store_6_sales_past_1',
#  'item_42_store_7_sales_past_1',
#  'item_42_store_8_sales_past_1',
#  'item_42_store_9_sales_past_1',
#  'item_43_store_10_sales_past_1',
#  'item_43_store_1_sales_past_1',
#  'item_43_store_2_sales_past_1',
#  'item_43_store_3_sales_past_1',
#  'item_43_store_4_sales_past_1',
#  'item_43_store_5_sales_past_1',
#  'item_43_store_6_sales_past_1',
#  'item_43_store_7_sales_past_1',
#  'item_43_store_8_sales_past_1',
#  'item_43_store_9_sales_past_1',
#  'item_44_store_10_sales_past_1',
#  'item_44_store_1_sales_past_1',
#  'item_44_store_2_sales_past_1',
#  'item_44_store_3_sales_past_1',
#  'item_44_store_4_sales_past_1',
#  'item_44_store_5_sales_past_1',
#  'item_44_store_6_sales_past_1',
#  'item_44_store_7_sales_past_1',
#  'item_44_store_8_sales_past_1',
#  'item_44_store_9_sales_past_1',
#  'item_45_store_10_sales_past_1',
#  'item_45_store_1_sales_past_1',
#  'item_45_store_2_sales_past_1',
#  'item_45_store_3_sales_past_1',
#  'item_45_store_4_sales_past_1',
#  'item_45_store_5_sales_past_1',
#  'item_45_store_6_sales_past_1',
#  'item_45_store_7_sales_past_1',
#  'item_45_store_8_sales_past_1',
#  'item_45_store_9_sales_past_1',
#  'item_46_store_10_sales_past_1',
#  'item_46_store_1_sales_past_1',
#  'item_46_store_2_sales_past_1',
#  'item_46_store_3_sales_past_1',
#  'item_46_store_4_sales_past_1',
#  'item_46_store_5_sales_past_1',
#  'item_46_store_6_sales_past_1',
#  'item_46_store_7_sales_past_1',
#  'item_46_store_8_sales_past_1',
#  'item_46_store_9_sales_past_1',
#  'item_47_store_10_sales_past_1',
#  'item_47_store_1_sales_past_1',
#  'item_47_store_2_sales_past_1',
#  'item_47_store_3_sales_past_1',
#  'item_47_store_4_sales_past_1',
#  'item_47_store_5_sales_past_1',
#  'item_47_store_6_sales_past_1',
#  'item_47_store_7_sales_past_1',
#  'item_47_store_8_sales_past_1',
#  'item_47_store_9_sales_past_1',
#  'item_48_store_10_sales_past_1',
#  'item_48_store_1_sales_past_1',
#  'item_48_store_2_sales_past_1',
#  'item_48_store_3_sales_past_1',
#  'item_48_store_4_sales_past_1',
#  'item_48_store_5_sales_past_1',
#  'item_48_store_6_sales_past_1',
#  'item_48_store_7_sales_past_1',
#  'item_48_store_8_sales_past_1',
#  'item_48_store_9_sales_past_1',
#  'item_49_store_10_sales_past_1',
#  'item_49_store_1_sales_past_1',
#  'item_49_store_2_sales_past_1',
#  'item_49_store_3_sales_past_1',
#  'item_49_store_4_sales_past_1',
#  'item_49_store_5_sales_past_1',
#  'item_49_store_6_sales_past_1',
#  'item_49_store_7_sales_past_1',
#  'item_49_store_8_sales_past_1',
#  'item_49_store_9_sales_past_1',
#  'item_4_store_10_sales_past_1',
#  'item_4_store_1_sales_past_1',
#  'item_4_store_2_sales_past_1',
#  'item_4_store_3_sales_past_1',
#  'item_4_store_4_sales_past_1',
#  'item_4_store_5_sales_past_1',
#  'item_4_store_6_sales_past_1',
#  'item_4_store_7_sales_past_1',
#  'item_4_store_8_sales_past_1',
#  'item_4_store_9_sales_past_1',
#  'item_50_store_10_sales_past_1',
#  'item_50_store_1_sales_past_1',
#  'item_50_store_2_sales_past_1',
#  'item_50_store_3_sales_past_1',
#  'item_50_store_4_sales_past_1',
#  'item_50_store_5_sales_past_1',
#  'item_50_store_6_sales_past_1',
#  'item_50_store_7_sales_past_1',
#  'item_50_store_8_sales_past_1',
#  'item_50_store_9_sales_past_1',
#  'item_5_store_10_sales_past_1',
#  'item_5_store_1_sales_past_1',
#  'item_5_store_2_sales_past_1',
#  'item_5_store_3_sales_past_1',
#  'item_5_store_4_sales_past_1',
#  'item_5_store_5_sales_past_1',
#  'item_5_store_6_sales_past_1',
#  'item_5_store_7_sales_past_1',
#  'item_5_store_8_sales_past_1',
#  'item_5_store_9_sales_past_1',
#  'item_6_store_10_sales_past_1',
#  'item_6_store_1_sales_past_1',
#  'item_6_store_2_sales_past_1',
#  'item_6_store_3_sales_past_1',
#  'item_6_store_4_sales_past_1',
#  'item_6_store_5_sales_past_1',
#  'item_6_store_6_sales_past_1',
#  'item_6_store_7_sales_past_1',
#  'item_6_store_8_sales_past_1',
#  'item_6_store_9_sales_past_1',
#  'item_7_store_10_sales_past_1',
#  'item_7_store_1_sales_past_1',
#  'item_7_store_2_sales_past_1',
#  'item_7_store_3_sales_past_1',
#  'item_7_store_4_sales_past_1',
#  'item_7_store_5_sales_past_1',
#  'item_7_store_6_sales_past_1',
#  'item_7_store_7_sales_past_1',
#  'item_7_store_8_sales_past_1',
#  'item_7_store_9_sales_past_1',
#  'item_8_store_10_sales_past_1',
#  'item_8_store_1_sales_past_1',
#  'item_8_store_2_sales_past_1',
#  'item_8_store_3_sales_past_1',
#  'item_8_store_4_sales_past_1',
#  'item_8_store_5_sales_past_1',
#  'item_8_store_6_sales_past_1',
#  'item_8_store_7_sales_past_1',
#  'item_8_store_8_sales_past_1',
#  'item_8_store_9_sales_past_1',
#  'item_9_store_10_sales_past_1',
#  'item_9_store_1_sales_past_1',
#  'item_9_store_2_sales_past_1',
#  'item_9_store_3_sales_past_1',
#  'item_9_store_4_sales_past_1',
#  'item_9_store_5_sales_past_1',
#  'item_9_store_6_sales_past_1',
#  'item_9_store_7_sales_past_1',
#  'item_9_store_8_sales_past_1',
#  'item_9_store_9_sales_past_1',
#  'weekday_0',
#  'weekday_1',
#  'weekday_2',
#  'weekday_3',
#  'weekday_4',
#  'weekday_5',
#  'weekday_6',
#  'month_1',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12']

# %%
X_colset = set(X_cols)
y_cols = [col for col in df_train.columns if col not in X_colset]

y = df_train[y_cols]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1825 entries, 2013-01-02 to 2017-12-31
# Freq: D
# Columns: 519 entries, item_10_store_10_sales_past_1 to month_12
# dtypes: float64(500), uint8(19)
# memory usage: 7.0 MB

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1825 entries, 2013-01-02 to 2017-12-31
# Freq: D
# Columns: 500 entries, item_10_store_10_sales to item_9_store_9_sales
# dtypes: float64(500)
# memory usage: 7.0 MB

# %%
X.columns
# Out:
# Index(['item_10_store_10_sales_past_1', 'item_10_store_1_sales_past_1',
#        'item_10_store_2_sales_past_1', 'item_10_store_3_sales_past_1',
#        'item_10_store_4_sales_past_1', 'item_10_store_5_sales_past_1',
#        'item_10_store_6_sales_past_1', 'item_10_store_7_sales_past_1',
#        'item_10_store_8_sales_past_1', 'item_10_store_9_sales_past_1',
#        ...
#        'month_3', 'month_4', 'month_5', 'month_6', 'month_7', 'month_8',
#        'month_9', 'month_10', 'month_11', 'month_12'],
#       dtype='object', length=519)

# %%
y.columns
# Out:
# Index(['item_10_store_10_sales', 'item_10_store_1_sales',
#        'item_10_store_2_sales', 'item_10_store_3_sales',
#        'item_10_store_4_sales', 'item_10_store_5_sales',
#        'item_10_store_6_sales', 'item_10_store_7_sales',
#        'item_10_store_8_sales', 'item_10_store_9_sales',
#        ...
#        'item_9_store_10_sales', 'item_9_store_1_sales', 'item_9_store_2_sales',
#        'item_9_store_3_sales', 'item_9_store_4_sales', 'item_9_store_5_sales',
#        'item_9_store_6_sales', 'item_9_store_7_sales', 'item_9_store_8_sales',
#        'item_9_store_9_sales'],
#       dtype='object', length=500)

# %%
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, shuffle=False)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# To achieve similar error values as on Kaggle, we will use only 1st quarter of 2017 for validation (test set contains 1st quarter of 2018 and the data is highly seasonal).

# %%
X_valid, y_valid = X_valid.head(90), y_valid.head(90)

# %% [markdown]
# For Keras, we need to make further transformations on input values:

# %%
X_train_vals = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_valid_vals = X_valid.values.reshape((X_valid.shape[0], 1, X_valid.shape[1]))

# %%
X_train_vals.shape
# Out:
# (1460, 1, 519)

# %%
X_train_vals
# Out:
# array([[[0.53846154, 0.39694656, 0.48      , ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.42307692, 0.33587786, 0.45714286, ..., 0.        ,
#          1.        , 0.        ]],
#
#        [[0.75      , 0.79389313, 0.80571429, ..., 0.        ,
#          0.        , 0.        ]],
#
#        ...,
#
#        [[0.33333333, 0.38931298, 0.38857143, ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.78846154, 0.89312977, 0.77714286, ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.80128205, 0.75572519, 0.79428571, ..., 0.        ,
#          0.        , 0.        ]]])

# %% [markdown]
# ### Defining models

# %%
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Conv1D, Input, Dropout, AvgPool1D, Reshape, Concatenate
# Out:
# Using TensorFlow backend.

# %%
X_train_vals.shape
# Out:
# (1460, 1, 519)

# %% [markdown]
# Simple LSTM model:

# %%
X_train_vals.shape[1], X_train_vals.shape[2]
# Out:
# (1, 519)

# %%
basic_model = Sequential()
basic_model.add(LSTM(500, input_shape=(X_train_vals.shape[1], X_train_vals.shape[2])))
basic_model.add(Dense(500))
basic_model.compile(loss='mean_absolute_error', optimizer='adam')

# %% [markdown]
# More complex model combining LSTM with convolutional layers:

# %%
inputs = Input(shape=(X_train_vals.shape[1], X_train_vals.shape[2]))
# top pipeline
top_lstm = LSTM(500)(inputs)
top_dense = Dense(500, activation='relu')(top_lstm)
top_dropout = Dropout(500)(top_dense)
# bottom pipeline
bottom_dense = Dense(500)(inputs)
bottom_conv1 = Conv1D(
    500, 
    kernel_size=1,
    input_shape=(X_train_vals.shape[1], X_train_vals.shape[2])
)(bottom_dense)
bottom_conv2 = Conv1D(
    1000,
    kernel_size=50,
    padding='same',
    activation='relu'
)(bottom_conv1)
bottom_conv3 = Conv1D(
    500,
    kernel_size=10,
    padding='same',
    activation='relu'
)(bottom_conv2)
bottom_pooling = AvgPool1D(
    pool_size=60, 
    padding='same'
)(bottom_conv3)
bottom_reshape = Reshape(
    target_shape=[500]
)(bottom_conv3)
# concat output from both pipelines
final_concat = Concatenate()([top_dropout, bottom_reshape])
final_dense = Dense(500)(final_concat)
# compile and return
complex_model = Model(inputs=inputs, outputs=final_dense)
complex_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mape'])

# %%
print(complex_model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1, 519)       0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 500)       260000      input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 1, 500)       250500      dense_3[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 500)          2040000     input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1, 1000)      25001000    conv1d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 500)          250500      lstm_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1, 500)       5000500     conv1d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 500)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 500)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1000)         0           dropout_1[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 500)          500500      concatenate_1[0][0]
# ==================================================================================================
# Total params: 33,303,000
# Trainable params: 33,303,000
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Now we can fit the models:

# %%
basic_history = basic_model.fit(
    X_train_vals, 
    y_train.values, 
    epochs=60, 
    batch_size=30,
    validation_data=(X_valid_vals, y_valid.values),
    verbose=2,
    shuffle=False
)

# %%
def plot_history(history):
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
plot_history(basic_history)

# %%
complex_history = complex_model.fit(
    X_train_vals, 
    y_train.values, 
    epochs=130, 
    batch_size=70,
    validation_data=(X_valid_vals, y_valid.values),
    verbose=2,
    shuffle=False
)

# %%
plot_history(complex_history)

# %% [markdown]
# ## Evaluating model predictions

# %%
def model_eval(model, X_test, y_test):
    """
    Evaluate (step-by-step) model predictions from X_test and return predictions and real values in comparable format.
    """
    # prepare data
    sales_x_cols = [col for col in X_test.columns if 'sales' in col]
    sales_x_idxs = [X_test.columns.get_loc(col) for col in sales_x_cols]
    sales_y_cols = [col for col in y_test.columns if 'sales' in col]
    sales_y_idxs = [y_test.columns.get_loc(col) for col in sales_y_cols]
    n_samples = y_test.shape[0]
    y_pred = np.zeros(y_test.shape)
    # iterate
    x_next = X_test.iloc[0].values
    for i in range(0, n_samples):
        x_arr = np.array([x_next])
        x_arr = x_arr.reshape(x_arr.shape[0], 1, x_arr.shape[1])
        y_pred[i] = model.predict(x_arr)[0] # input for prediction must be 2d, output is immediately extracted from 2d to 1d
        try:
            x_next = X_test.iloc[i+1].values
            x_next[sales_x_idxs] = y_pred[i][sales_y_idxs]
        except IndexError:
            pass  # this happens on last iteration, and x_next does not matter anymore
    return y_pred, y_test.values


def unscale(y_arr, scaler, template_df, toint=False):
    """
    Unscale array y_arr of model predictions, based on a scaler fitted 
    to template_df.
    """
    tmp = template_df.copy()
    tmp[y_cols] = pd.DataFrame(y_arr, index=tmp.index)
    tmp[cols_to_scale] = scaler.inverse_transform(tmp[cols_to_scale])
    if toint:
        return tmp[y_cols].astype(int)
    return tmp[y_cols]


def vector_smape(y_pred, y_real):
    nom = np.abs(y_pred-y_real)
    denom = (np.abs(y_pred) + np.abs(y_real)) / 2
    results = nom / denom
    return 100*np.mean(results)  # in percent, same as at kaggle

# %%
y_pred_basic, y_real = model_eval(basic_model, X_valid, y_valid)

# %%
y_pred_complex = model_eval(complex_model, X_valid, y_valid)[0]

# %%
# this is just for unscaling
template_df = pd.concat([X_valid, y_valid], axis=1)
template_df['is_test'] = np.repeat(True, template_df.shape[0])

# %%
basic_pred = unscale(y_pred_basic, scaler, template_df, toint=True)
complex_pred = unscale(y_pred_complex, scaler, template_df, toint=True)
real = unscale(y_real, scaler, template_df, toint=True)

# %%
basic_smapes = [vector_smape(basic_pred[col], real[col]) for col in basic_pred.columns]
complex_smapes = [vector_smape(complex_pred[col], real[col]) for col in complex_pred.columns]

# %%
sns.distplot(basic_smapes, label='Basic model')
sns.distplot(complex_smapes, label='Complex model')
plt.legend(loc='upper right')
plt.savefig('smape_basic_vs_complex.svg')
plt.show()

# %% [markdown]
# Depending on training parameters, basic model can sometimes achieve results comparable to the complex one, however after uploading to Kaggle complex model achieved better (and more consistent) results.

# %%
describe(basic_smapes)

# %%
describe(complex_smapes)

# %% [markdown]
# ### Visualizing model prediction
# We will plot predictions of 2 models for a sample store and item.

# %%
store, item = 1,1
plot_lengths = [7, 30, 90]
rolling_mean_windows = [1, 1, 2]  # to make plots more readable

# %%
basic_pred

# %%
storeitem_col = f'item_{item}_store_{store}_sales'

for pl, mw in zip(plot_lengths, rolling_mean_windows):
    plt.plot(basic_pred[storeitem_col].rolling(mw).mean().values[:pl],
             color_scheme['blue'],
             lw=2,
             label='Basic model prediction')
    plt.plot(complex_pred[storeitem_col].rolling(mw).mean().values[:pl],
             color_scheme['green'],
             lw=2, 
             label='Complex model prediction')
    plt.plot(real[storeitem_col].rolling(mw).mean().values[:pl],
             color_scheme['black'],
             lw=2, 
             label='Real values')
    plt.legend(loc='upper left')
    plt.savefig(f'plot_prediction_{pl}_{mw}.svg')
    plt.show()

# %%
df1 = basic_pred['item_1_store_1_sales']
df1.rolling(1).mean().values

# %%
storeitem_col

# %%
for pl, mw in zip(plot_lengths, rolling_mean_windows):
    print('pl: '+ str(pl) + ' mw: '+ str(mw))

# %%
complex_pred['item_1_store_1_sales']

# %%
inputs = Input(shape=(X_train_vals.shape[1], X_train_vals.shape[2]))
# top pipeline
top_lstm = LSTM(500)(inputs)
top_dense = Dense(500, activation='relu')(top_lstm)
top_dropout = Dropout(500)(top_dense)
# bottom pipeline
bottom_dense = Dense(500)(inputs)
bottom_conv1 = Conv1D(500,kernel_size=1,input_shape=(X_train_vals.shape[1], X_train_vals.shape[2]))(bottom_dense)
bottom_conv2 = Conv1D(1000,kernel_size=50,padding='same',activation='relu')(bottom_conv1)
bottom_conv3 = Conv1D(500,kernel_size=10,padding='same',activation='relu')(bottom_conv2)
bottom_pooling = AvgPool1D(pool_size=60,padding='same')(bottom_conv3)
bottom_reshape = Reshape(target_shape=[500])(bottom_conv3)
# concat output from both pipelines
final_concat = Concatenate()([top_dropout, bottom_reshape])
final_dense = Dense(500)(final_concat)
# compile and return
complex_model = Model(inputs=inputs, outputs=final_dense)
complex_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mape'])

# %%
X_train_vals.shape[1], X_train_vals.shape[2]
# 1, 519
